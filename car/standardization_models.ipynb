# %% [markdown]
# ## Model with Standardization

# %%
# import pandas library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv("final_cars.csv")

# %%
## create X and Y
y = cars['price']
X = cars.drop(columns=['price'])

# %%
X  = pd.get_dummies(X)

# %%
X.columns
# Out:
# Index(['length', 'width', 'curb-weight', 'engine-size', 'highway-mpg',
#        'make_alfa-romero', 'make_audi', 'make_bmw', 'make_chevrolet',
#        'make_dodge', 'make_honda', 'make_isuzu', 'make_jaguar', 'make_mazda',
#        'make_mercedes-benz', 'make_mercury', 'make_mitsubishi', 'make_nissan',
#        'make_peugot', 'make_plymouth', 'make_porsche', 'make_renault',
#        'make_saab', 'make_subaru', 'make_toyota', 'make_volkswagen',
#        'make_volvo', 'fuel-type_diesel', 'fuel-type_gas', 'num-of-doors_four',
#        'num-of-doors_two', 'body-style_convertible', 'body-style_hardtop',
#        'body-style_hatchback', 'body-style_sedan', 'body-style_wagon',
#        'drive-wheels_4wd', 'drive-wheels_fwd', 'drive-wheels_rwd'],
#       dtype='object')

# %%
features_to_scale = ['length', 'width', 'curb-weight', 'engine-size', 'highway-mpg']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=99)

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train.head()
# Out:
#      length  width  curb-weight  engine-size  highway-mpg  make_alfa-romero  \
# 134   156.9   63.4         2050           97           36                 0
# 145   173.6   65.4         2650          108           23                 0
# 16    197.0   70.9         3505          209           20                 0
# 54    169.0   65.7         2385           70           23                 0
# 85    172.4   65.4         2403          110           30                 0
#
#      make_audi  make_bmw  make_chevrolet  make_dodge  ...  num-of-doors_four  \
# 134          0         0               0           0  ...                  0
# 145          0         0               0           0  ...                  1
# 16           0         1               0           0  ...                  1
# 54           0         0               0           0  ...                  0
# 85           0         0               0           0  ...                  1
#
# ...

# %%
X_train_dummies = X_train.drop(columns=features_to_scale)
X_test_dummies = X_test.drop(columns=features_to_scale)

# %%
X_train_dummies.head()
# Out:
#      make_alfa-romero  make_audi  make_bmw  make_chevrolet  make_dodge  \
# 134                 0          0         0               0           0
# 145                 0          0         0               0           0
# 16                  0          0         1               0           0
# 54                  0          0         0               0           0
# 85                  0          0         0               0           0
#
#      make_honda  make_isuzu  make_jaguar  make_mazda  make_mercedes-benz  ...  \
# 134           0           0            0           0                   0  ...
# 145           0           0            0           0                   0  ...
# 16            0           0            0           0                   0  ...
# 54            0           0            0           1                   0  ...
# 85            0           0            0           0                   0  ...
#
#      num-of-doors_four  num-of-doors_two  body-style_convertible  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
## Scale X_train and X_test
X_train_scaled = scaler.fit_transform(X_train[features_to_scale])
X_test_scaled = scaler.transform(X_test[features_to_scale])

# %%
X_train_scaled = pd.DataFrame(X_train,columns = features_to_scale)

# %%
X_test_scaled = pd.DataFrame(X_test,columns = features_to_scale)

# %%
X_train = pd.concat([X_train_dummies, X_train_scaled], axis=1)
X_test = pd.concat([X_test_dummies, X_test_scaled], axis=1)

# %%
X_train.head()
# Out:
#      make_alfa-romero  make_audi  make_bmw  make_chevrolet  make_dodge  \
# 134                 0          0         0               0           0
# 145                 0          0         0               0           0
# 16                  0          0         1               0           0
# 54                  0          0         0               0           0
# 85                  0          0         0               0           0
#
#      make_honda  make_isuzu  make_jaguar  make_mazda  make_mercedes-benz  ...  \
# 134           0           0            0           0                   0  ...
# 145           0           0            0           0                   0  ...
# 16            0           0            0           0                   0  ...
# 54            0           0            0           1                   0  ...
# 85            0           0            0           0                   0  ...
#
# ...

# %%
X_test.head()
# Out:
#      make_alfa-romero  make_audi  make_bmw  make_chevrolet  make_dodge  \
# 71                  0          0         0               0           0
# 24                  0          0         0               0           1
# 51                  0          0         0               0           0
# 174                 0          0         0               0           0
# 97                  0          0         0               0           0
#
#      make_honda  make_isuzu  make_jaguar  make_mazda  make_mercedes-benz  ...  \
# 71            0           0            0           0                   1  ...
# 24            0           0            0           0                   0  ...
# 51            0           0            0           1                   0  ...
# 174           0           0            0           0                   0  ...
# 97            0           0            0           0                   0  ...
#
# ...

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(X_test)

# %%
## get MSE 
mse = mean_squared_error(y_test,y_pred)
print(f"Mean Squared Error : {mse:0.2f}")

rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print(f"Root Mean Squared Error : {rmse:0.2f}")

mae = mean_absolute_error(y_test,y_pred)
print(f"Mean Absolute Error : {mae:0.2f}")

r2score = r2_score(y_test,y_pred)
print(f"R2 Score: {r2score:0.2f}")
# Out:
# Mean Squared Error : 6304877.08
# Root Mean Squared Error : 2510.95
# Mean Absolute Error : 1668.38
# R2 Score: 0.93
